# %%
import pandas as pd

# %%
pd.read_csv("extracted_parameters.csv")
# Out:
#         category                             precursor temperature       pH  \
# 0   Metal Oxides  Zinc nitrate, Hexamethylenetetramine  100-120 °C  7.5-8.5
# 1   Metal Oxides                          Zinc nitrate  220-100 °C      NaN
# 2   Metal Oxides                Zinc acetate dihydrate      300 °C      NaN
# 3   Metal Oxides               CuCl2·2H2O, C18H29NaO3S      120 °C      NaN
# 4   Metal Oxides                 Cu(CH3COO)2·H2O, NaOH      180 °C      NaN
# 5   Metal Oxides                   FeCl3·6H2O, NaH2PO4      240 °C      4.5
# 6   Metal Oxides                   Fe(NO3)3·9H2O, urea      140 °C      NaN
# 7   Metal Oxides                         Cd(NO3)2, KOH      260 °C      NaN
# 8   Metal Oxides    Cd(NO3)2·4H2O, polyethylene glycol      180 °C      NaN
# 9   Metal Oxides                         Titanium foil  130-180 °C      NaN
# 10  Metal Oxides              (NH4)2CO3, Al(NO3)3·9H2O      100 °C      NaN
# ...
